# %%
from ourPolynomial import *
from ProgrammaEPG import *
from Rette import *

#Brutto bastardo perché non mi togli il rumore?

h1 = parse("2cos^2(x) + 4cos(y)")
h2 = parse("sen^3(x) + 3sen^2(y)")
xh,epgh,improperh,titlh = EPG(h1,h2,100,10)

EPG_plot(epgh,titlh)

# %%
xh,epgh,titlh = noise_reduction(xh,h1,h2,10,titlh,improperh)

EPG_plot(epgh,titlh)
