# %% [markdown]
# Voglio fare delle prove per vedere quanti punti si plottano nei diversi EPG // quanti di loro beccano le rette

# %%
from ourPolynomial import *
from ProgrammaEPG import *
from Rette import *

#Esempio grado 3

h1 = parse("2cos^2(x) + 4cos(y)")
h2 = parse("sen^3(x) + 3sen^2(y)")

print(h1)

h1ppc,h2ppc = EPG(h1,h2,200,0.01,0.7,True)
print(len(h1ppc))
# Out:
# 2cos^2(x)+4cos(y)
# 8293

# %% [markdown]
# Adesso interseco l'EPG con un fascio di 20 rette parallele. Per cambiare la quantità di rette o il valore di epsilon=0.1 andare in Rette.py.

# %%
lista = intersect_sheaf_type1(h1ppc,h2ppc)

# %% [markdown]
# Adesso faccio la stessa prova con un fascio di 20 rette che passano per (0,1). Per cambiare questo punto andare in Rette.py

# %%
lista = intersect_sheaf_type2(h1ppc,h2ppc)

# %% [markdown]
# Adesso faccio le stesse prove con gli esempi di grado 2 e 1

# %%
#Esempio grado 2

g1 = parse("cosxseny")
g2 = parse("senxseny + cosy")

g1ppc,g2ppc = EPG(g1,g2,200,0.01,0.1,True)
print(len(g1ppc))
# Out:
# 3271

# %%
lista = intersect_sheaf_type1(g1ppc,g2ppc)

# %%
lista = intersect_sheaf_type2(g1ppc,g2ppc)

# %%
#Esempio grado 1

f1 = parse("cos(x)+cos(y)")
f2 = parse("sen(x)+sen(y)")

f1ppc,f2ppc = EPG(f1,f2,200,0.01,0.1,True)
print(len(f1ppc))
# Out:
# 1673

# %%
lista = intersect_sheaf_type1(f1ppc,f2ppc)

# %%
lista = intersect_sheaf_type2(f1ppc,f2ppc)
